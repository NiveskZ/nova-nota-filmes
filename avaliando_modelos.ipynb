# %%
import requests
import pandas as pd

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

# %%
dtr_model_1 = DecisionTreeRegressor(random_state=1)

forest_model_1 = RandomForestRegressor(n_estimators=50,criterion="absolute_error",random_state=1)
forest_model_2 = RandomForestRegressor(n_estimators=100,random_state=1)
forest_model_3 = RandomForestRegressor(n_estimators=100,criterion="friedman_mse",random_state=1)
forest_model_4 = RandomForestRegressor(n_estimators=100,criterion="absolute_error",random_state=1)
forest_model_5 = RandomForestRegressor(n_estimators=200,criterion="absolute_error",random_state=1)

forest_models = [forest_model_1,forest_model_2,forest_model_3,forest_model_4,forest_model_5]

# %%
my_rating_df = pd.read_csv('ratings.csv') # Lista com todos os meus filmes e minhas notas
my_rating_df.head()
# Out:
#          Date                         Name  Year        Letterboxd URI  Rating
# 0  2021-11-29                       Violet  2021  https://boxd.it/oMCE     4.0
# 1  2021-11-29                     Hot Fuzz  2007  https://boxd.it/2416     3.5
# 2  2021-11-29              The World's End  2013  https://boxd.it/3EiO     3.0
# 3  2021-11-29  Scott Pilgrim vs. the World  2010  https://boxd.it/1Aq6     4.0
# 4  2021-11-29                   La La Land  2016  https://boxd.it/a5fa     3.0

# %%
# Minhas configurações e API KEYs
import json

with open("config.json","r") as file:
    config = json.load(file)

# %%
from rapidfuzz import process, fuzz
from unidecode import unidecode
import time


# CONFIGURAÇÕES INICIAIS

test_df = my_rating_df.head(10)  # DataFrame de teste

API_KEY = config['TMDB_API_KEY']  
session = requests.Session()  
tmdb_rating = []  # Lista para armazenar resultados


# PRÉ-AQUECIMENTO DA CONEXÃO (COLD START FIX)

try:
    session.get(
        "https://api.themoviedb.org/3/search/movie",
        params={
            'api_key': API_KEY,
            'query': "dummy",
            'year': 2023
        },
        timeout=10
    )
except Exception as e:
    print(f"Aquecimento falhou (não crítico): {str(e)}", flush=True)

# %%
# SOLICITANDO DETALHES DE TODOS OS MEUS FILMES NA API DO TMDB

start_total = time.time()

for row in my_rating_df.itertuples():
    filme = row.Name
    ano_original = int(row.Year)
    print(f"\n--- Processando: {filme} ({ano_original}) ---", flush=True)
    
    try:
        # ETAPA 1: BUSCA NA API
        print(f"Enviando requisição...", flush=True)
        response = session.get(
            "https://api.themoviedb.org/3/search/movie",
            params={
                'api_key': API_KEY,
                'query': unidecode(filme).lower(),
                'year': ano_original,
                'page': 1
            },
            timeout=15
        )
        
        if response.status_code != 200:
            print(f"Erro na API: {response.status_code}", flush=True)
            continue
            
        data = response.json()
        results = data.get('results', [])[:5]  # Limita a 5 resultados
        
        # ETAPA 2: SELEÇÃO DO MELHOR MATCH
        best_match = None
        best_score = 0
        best_year_diff = float('inf')
        
        for result in results:
            # Compara títulos
            title_tmdb = unidecode(result.get('title', '')).lower()
            original_title = unidecode(result.get('original_title', title_tmdb)).lower()
            
            # Calcula similaridade
            score = max(
                fuzz.ratio(unidecode(filme).lower(), title_tmdb),
                fuzz.ratio(unidecode(filme).lower(), original_title)
            )
            
            # Verifica ano
            release_date = result.get('release_date', '')
            try:
                release_year = int(release_date[:4]) if release_date else None
            except ValueError:
                release_year = None
            
            year_diff = abs(release_year - ano_original) if release_year else 9999
            
            # Critérios de prioridade
            if score > 85 and year_diff <= 2:
                if (score > best_score) or \
                   (score == best_score and year_diff < best_year_diff):
                    
                    best_match = result
                    best_score = score
                    best_year_diff = year_diff
        
        if not best_match:
            print(f"Nenhum match válido", flush=True)
            continue
            
        # ETAPA 3: VERIFICAÇÃO DE DUPLICATAS
        movie_id = best_match['id']
        print(f"Buscando detalhes (ID: {movie_id})...", flush=True)
        # Verifica se já foi adicionado (por ID)
        duplicate = any(
            (item['tmdb_id'] == movie_id) 
            for item in tmdb_rating
        )
        
        if duplicate:
            for item in tmdb_rating:
                print(item)
            print(f"Duplicata evitada: {filme} ({ano_original})", flush=True)
            continue
            
        # ETAPA 4: BUSCA DE DETALHES
        response_details = session.get(
            f"https://api.themoviedb.org/3/movie/{movie_id}",
            params={'api_key': API_KEY},
            timeout=15
        )
        
        if response_details.status_code != 200:
            print(f"Erro nos detalhes: {response_details.status_code}", flush=True)
            continue
            
        details = response_details.json()
        
        # ETAPA 5: ARMAZENAMENTO DOS DADOS
        tmdb_rating.append({
            'title': filme,
            'tmdb_id': movie_id,
            'tmdb_title': details.get('title'),
            'year': details.get('release_date')[:4] if details.get('release_date') else None,
            'genre_ids': [genre['id'] for genre in details.get('genres',[])],
            'original_language': details.get('original_language'),
            'popularity': details.get('popularity'),
            'vote_count': details.get('vote_count'),
            'vote_average': details.get('vote_average'),
            'budget': details.get('budget'),
            'revenue': details.get('revenue'),
            'runtime': details.get('runtime'),
            'production_company_id': details.get('production_companies', [{}])[0].get('id') if details.get('production_companies') else None
        })
        print(f"Adicionado: {details.get('title')} ({movie_id}) | Tempo: {time.time() - start_total:.2f}s")
        
    except Exception as e:
        print(f"Erro: {str(e)}", flush=True)


# PÓS-PROCESSAMENTO

tmdb_rating_df = pd.DataFrame(tmdb_rating)

# Verificação final
print(f"\nTotal original: {len(my_rating_df)}")
print(f"Total encontrado: {len(tmdb_rating_df)}")

# Remove duplicatas residuais por ID
tmdb_rating_df = tmdb_rating_df.drop_duplicates(subset=['tmdb_id'])

print(f"\nResultado final: {len(tmdb_rating_df)} registros")
print(f"Tempo total: {time.time() - start_total:.2f}s")
# Out:
# --- Processando: Violet (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 665901)...
# Adicionado: Violet (665901) | Tempo: 0.24s
#
# --- Processando: Hot Fuzz (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 4638)...
# Adicionado: Hot Fuzz (4638) | Tempo: 0.48s
#
# --- Processando: The World's End (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 107985)...
# Adicionado: The World's End (107985) | Tempo: 0.75s
#
# --- Processando: Scott Pilgrim vs. the World (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 22538)...
# Adicionado: Scott Pilgrim vs. the World (22538) | Tempo: 0.98s
#
# --- Processando: La La Land (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 313369)...
# Adicionado: La La Land (313369) | Tempo: 1.22s
#
# --- Processando: Attack the Block (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 59678)...
# Adicionado: Attack the Block (59678) | Tempo: 1.46s
#
# --- Processando: Dune (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 438631)...
# Adicionado: Dune (438631) | Tempo: 1.70s
#
# --- Processando: Pulp Fiction (1994) ---
# Enviando requisição...
# Buscando detalhes (ID: 680)...
# Adicionado: Pulp Fiction (680) | Tempo: 1.94s
#
# --- Processando: Once Upon a Time... in Hollywood (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 466272)...
# Adicionado: Once Upon a Time... in Hollywood (466272) | Tempo: 2.17s
#
# --- Processando: Inglourious Basterds (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 16869)...
# Adicionado: Inglourious Basterds (16869) | Tempo: 2.41s
#
# --- Processando: Django Unchained (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 68718)...
# Adicionado: Django Unchained (68718) | Tempo: 2.64s
#
# --- Processando: The Hateful Eight (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 273248)...
# Adicionado: The Hateful Eight (273248) | Tempo: 2.88s
#
# --- Processando: Jackie Brown (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 184)...
# Adicionado: Jackie Brown (184) | Tempo: 3.11s
#
# --- Processando: Four Rooms (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 5)...
# Adicionado: Four Rooms (5) | Tempo: 3.35s
#
# --- Processando: Pitch Perfect (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 114150)...
# Adicionado: Pitch Perfect (114150) | Tempo: 3.58s
#
# --- Processando: Pitch Perfect 2 (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 254470)...
# Adicionado: Pitch Perfect 2 (254470) | Tempo: 3.81s
#
# --- Processando: The Good Dinosaur (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 105864)...
# Adicionado: The Good Dinosaur (105864) | Tempo: 4.05s
#
# --- Processando: Brave (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 62177)...
# Adicionado: Brave (62177) | Tempo: 4.29s
#
# --- Processando: A Bug's Life (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 9487)...
# Adicionado: A Bug's Life (9487) | Tempo: 4.52s
#
# --- Processando: Onward (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 508439)...
# Adicionado: Onward (508439) | Tempo: 4.75s
#
# --- Processando: Soul (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 508442)...
# Adicionado: Soul (508442) | Tempo: 5.00s
#
# --- Processando: Monsters University (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 62211)...
# Adicionado: Monsters University (62211) | Tempo: 5.23s
#
# --- Processando: WALL·E (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 10681)...
# Adicionado: WALL·E (10681) | Tempo: 5.47s
#
# --- Processando: Cars (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 920)...
# Adicionado: Cars (920) | Tempo: 5.71s
#
# --- Processando: Monsters, Inc. (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 585)...
# Adicionado: Monsters, Inc. (585) | Tempo: 5.97s
#
# --- Processando: Finding Nemo (2003) ---
# Enviando requisição...
# Buscando detalhes (ID: 12)...
# Adicionado: Finding Nemo (12) | Tempo: 6.20s
#
# --- Processando: Incredibles 2 (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 260513)...
# Adicionado: Incredibles 2 (260513) | Tempo: 6.44s
#
# --- Processando: Inside Out (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 150540)...
# Adicionado: Inside Out (150540) | Tempo: 6.67s
#
# --- Processando: Coco (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 354912)...
# Adicionado: Coco (354912) | Tempo: 6.91s
#
# --- Processando: Toy Story 3 (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 10193)...
# Adicionado: Toy Story 3 (10193) | Tempo: 7.15s
#
# --- Processando: Spider-Man 2 (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 558)...
# Adicionado: Spider-Man 2 (558) | Tempo: 7.38s
#
# --- Processando: Get Out (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 419430)...
# Adicionado: Get Out (419430) | Tempo: 7.62s
#
# --- Processando: Us (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 458723)...
# Adicionado: Us (458723) | Tempo: 7.86s
#
# --- Processando: Joker (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 475557)...
# Adicionado: Joker (475557) | Tempo: 8.11s
#
# --- Processando: BlacKkKlansman (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 487558)...
# Adicionado: BlacKkKlansman (487558) | Tempo: 8.34s
#
# --- Processando: Ring (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 2671)...
# Adicionado: Ring (2671) | Tempo: 8.58s
#
# --- Processando: The Ring (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 565)...
# Adicionado: The Ring (565) | Tempo: 8.81s
#
# --- Processando: Ju-on: The Grudge (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 11838)...
# Adicionado: Ju-on: The Grudge (11838) | Tempo: 9.05s
#
# --- Processando: The Handmaiden (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 290098)...
# Adicionado: The Handmaiden (290098) | Tempo: 9.28s
#
# --- Processando: The Call (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 746817)...
# Adicionado: The Call (746817) | Tempo: 9.52s
#
# --- Processando: Candyman (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 565028)...
# Adicionado: Candyman (565028) | Tempo: 9.75s
#
# --- Processando: Don't Breathe (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 300669)...
# Adicionado: Don't Breathe (300669) | Tempo: 9.98s
#
# --- Processando: It (1990) ---
# Enviando requisição...
# Nenhum match válido
#
# --- Processando: It (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 346364)...
# Adicionado: It (346364) | Tempo: 10.34s
#
# --- Processando: It Chapter Two (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 474350)...
# Adicionado: It Chapter Two (474350) | Tempo: 10.58s
#
# --- Processando: World War Z (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 72190)...
# Adicionado: World War Z (72190) | Tempo: 10.81s
#
# --- Processando: Hush (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 376570)...
# Adicionado: Hush (376570) | Tempo: 11.05s
#
# --- Processando: Unfriended (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 277685)...
# Adicionado: Unfriended (277685) | Tempo: 11.28s
#
# --- Processando: Scream (1996) ---
# Enviando requisição...
# Buscando detalhes (ID: 4232)...
# Adicionado: Scream (4232) | Tempo: 11.52s
#
# --- Processando: A Quiet Place (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 447332)...
# Adicionado: A Quiet Place (447332) | Tempo: 11.75s
#
# --- Processando: Cloverfield (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 7191)...
# Adicionado: Cloverfield (7191) | Tempo: 11.98s
#
# --- Processando: Split (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 358364)...
# Adicionado: Split (358364) | Tempo: 12.22s
#
# --- Processando: Unbreakable (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 9741)...
# Adicionado: Unbreakable (9741) | Tempo: 12.46s
#
# --- Processando: Glass (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 450465)...
# Adicionado: Glass (450465) | Tempo: 12.70s
#
# --- Processando: The Sixth Sense (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 745)...
# Adicionado: The Sixth Sense (745) | Tempo: 12.96s
#
# --- Processando: The Last Airbender (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 10196)...
# Adicionado: The Last Airbender (10196) | Tempo: 13.19s
#
# --- Processando: Rocky (1976) ---
# Enviando requisição...
# Buscando detalhes (ID: 1366)...
# Adicionado: Rocky (1366) | Tempo: 13.43s
#
# --- Processando: Rocky V (1990) ---
# Enviando requisição...
# Buscando detalhes (ID: 1375)...
# Adicionado: Rocky V (1375) | Tempo: 13.67s
#
# --- Processando: Rocky II (1979) ---
# Enviando requisição...
# Buscando detalhes (ID: 1367)...
# Adicionado: Rocky II (1367) | Tempo: 13.90s
#
# --- Processando: Rocky III (1982) ---
# Enviando requisição...
# Buscando detalhes (ID: 1371)...
# Adicionado: Rocky III (1371) | Tempo: 14.13s
#
# --- Processando: Rocky IV (1985) ---
# Enviando requisição...
# Buscando detalhes (ID: 1374)...
# Adicionado: Rocky IV (1374) | Tempo: 14.36s
#
# --- Processando: Rocky Balboa (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 1246)...
# Adicionado: Rocky Balboa (1246) | Tempo: 14.60s
#
# --- Processando: The Expendables (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 27578)...
# Adicionado: The Expendables (27578) | Tempo: 14.84s
#
# --- Processando: Creed (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 312221)...
# Adicionado: Creed (312221) | Tempo: 15.07s
#
# --- Processando: Bruce Almighty (2003) ---
# Enviando requisição...
# Buscando detalhes (ID: 310)...
# Adicionado: Bruce Almighty (310) | Tempo: 15.31s
#
# --- Processando: Lemony Snicket's A Series of Unfortunate Events (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 11774)...
# Adicionado: Lemony Snicket's A Series of Unfortunate Events (11774) | Tempo: 15.54s
#
# --- Processando: Liar Liar (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 1624)...
# Adicionado: Liar Liar (1624) | Tempo: 15.78s
#
# --- Processando: A Christmas Carol (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 17979)...
# Adicionado: A Christmas Carol (17979) | Tempo: 16.01s
#
# --- Processando: Kick-Ass 2 (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 59859)...
# Adicionado: Kick-Ass 2 (59859) | Tempo: 16.25s
#
# --- Processando: The Cable Guy (1996) ---
# Enviando requisição...
# Buscando detalhes (ID: 9894)...
# Adicionado: The Cable Guy (9894) | Tempo: 16.48s
#
# --- Processando: Ace Ventura: When Nature Calls (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 9273)...
# Adicionado: Ace Ventura: When Nature Calls (9273) | Tempo: 16.72s
#
# --- Processando: Me, Myself & Irene (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 2123)...
# Adicionado: Me, Myself & Irene (2123) | Tempo: 17.00s
#
# --- Processando: Mr. Popper's Penguins (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 58224)...
# Adicionado: Mr. Popper's Penguins (58224) | Tempo: 17.23s
#
# --- Processando: Knives Out (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 546554)...
# Adicionado: Knives Out (546554) | Tempo: 17.47s
#
# --- Processando: Midsommar (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 530385)...
# Adicionado: Midsommar (530385) | Tempo: 17.70s
#
# --- Processando: Avengers: Endgame (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 299534)...
# Adicionado: Avengers: Endgame (299534) | Tempo: 17.94s
#
# --- Processando: The Amazing Spider-Man 2 (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 102382)...
# Adicionado: The Amazing Spider-Man 2 (102382) | Tempo: 18.17s
#
# --- Processando: Avengers: Infinity War (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 299536)...
# Adicionado: Avengers: Infinity War (299536) | Tempo: 18.41s
#
# --- Processando: The Shining (1980) ---
# Enviando requisição...
# Buscando detalhes (ID: 694)...
# Adicionado: The Shining (694) | Tempo: 18.64s
#
# --- Processando: Spider-Man: Homecoming (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 315635)...
# Adicionado: Spider-Man: Homecoming (315635) | Tempo: 18.87s
#
# --- Processando: Suicide Squad (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 297761)...
# Adicionado: Suicide Squad (297761) | Tempo: 19.11s
#
# --- Processando: I Am Legend (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 6479)...
# Adicionado: I Am Legend (6479) | Tempo: 19.35s
#
# --- Processando: The Pursuit of Happyness (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 1402)...
# Adicionado: The Pursuit of Happyness (1402) | Tempo: 19.58s
#
# --- Processando: Bad Boys (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 9737)...
# Adicionado: Bad Boys (9737) | Tempo: 19.81s
#
# --- Processando: Bad Boys II (2003) ---
# Enviando requisição...
# Buscando detalhes (ID: 8961)...
# Adicionado: Bad Boys II (8961) | Tempo: 20.05s
#
# --- Processando: The Avengers (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 24428)...
# Adicionado: The Avengers (24428) | Tempo: 20.29s
#
# --- Processando: The Perks of Being a Wallflower (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 84892)...
# Adicionado: The Perks of Being a Wallflower (84892) | Tempo: 20.53s
#
# --- Processando: Deadpool (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 293660)...
# Adicionado: Deadpool (293660) | Tempo: 20.76s
#
# --- Processando: Doctor Strange (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 284052)...
# Adicionado: Doctor Strange (284052) | Tempo: 21.00s
#
# --- Processando: Captain America: Civil War (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 271110)...
# Adicionado: Captain America: Civil War (271110) | Tempo: 21.23s
#
# --- Processando: Nightcrawler (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 242582)...
# Adicionado: Nightcrawler (242582) | Tempo: 21.46s
#
# --- Processando: Captain America: The Winter Soldier (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 100402)...
# Adicionado: Captain America: The Winter Soldier (100402) | Tempo: 21.71s
#
# --- Processando: Good Will Hunting (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 489)...
# Adicionado: Good Will Hunting (489) | Tempo: 21.94s
#
# --- Processando: A Clockwork Orange (1971) ---
# Enviando requisição...
# Buscando detalhes (ID: 185)...
# Adicionado: A Clockwork Orange (185) | Tempo: 22.17s
#
# --- Processando: Léon: The Professional (1994) ---
# Enviando requisição...
# Buscando detalhes (ID: 101)...
# Adicionado: Léon: The Professional (101) | Tempo: 22.41s
#
# --- Processando: (500) Days of Summer (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 19913)...
# Adicionado: (500) Days of Summer (19913) | Tempo: 22.64s
#
# --- Processando: Captain Marvel (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 299537)...
# Adicionado: Captain Marvel (299537) | Tempo: 22.88s
#
# --- Processando: Avengers: Age of Ultron (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 99861)...
# Adicionado: Avengers: Age of Ultron (99861) | Tempo: 23.12s
#
# --- Processando: Star Wars: The Force Awakens (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 140607)...
# Adicionado: Star Wars: The Force Awakens (140607) | Tempo: 23.35s
#
# --- Processando: Captain America: The First Avenger (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 1771)...
# Adicionado: Captain America: The First Avenger (1771) | Tempo: 23.59s
#
# --- Processando: Iron Man 3 (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 68721)...
# Adicionado: Iron Man 3 (68721) | Tempo: 23.82s
#
# --- Processando: Coraline (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 14836)...
# Adicionado: Coraline (14836) | Tempo: 24.05s
#
# --- Processando: Iron Man 2 (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 10138)...
# Adicionado: Iron Man 2 (10138) | Tempo: 24.29s
#
# --- Processando: Thor (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 10195)...
# Adicionado: Thor (10195) | Tempo: 24.53s
#
# --- Processando: The Lion King (1994) ---
# Enviando requisição...
# Buscando detalhes (ID: 8587)...
# Adicionado: The Lion King (8587) | Tempo: 24.76s
#
# --- Processando: Your Name. (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 372058)...
# Adicionado: Your Name. (372058) | Tempo: 25.00s
#
# --- Processando: Juno (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 7326)...
# Adicionado: Juno (7326) | Tempo: 25.23s
#
# --- Processando: Thor: The Dark World (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 76338)...
# Adicionado: Thor: The Dark World (76338) | Tempo: 25.46s
#
# --- Processando: Wonder Woman (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 297762)...
# Adicionado: Wonder Woman (297762) | Tempo: 25.70s
#
# --- Processando: Kingsman: The Secret Service (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 207703)...
# Adicionado: Kingsman: The Secret Service (207703) | Tempo: 25.97s
#
# --- Processando: Zootopia (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 269149)...
# Adicionado: Zootopia (269149) | Tempo: 26.20s
#
# --- Processando: Big Hero 6 (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 177572)...
# Adicionado: Big Hero 6 (177572) | Tempo: 26.43s
#
# --- Processando: Frozen (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 109445)...
# Adicionado: Frozen (109445) | Tempo: 26.67s
#
# --- Processando: Silver Linings Playbook (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 82693)...
# Adicionado: Silver Linings Playbook (82693) | Tempo: 26.90s
#
# --- Processando: The Nice Guys (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 290250)...
# Adicionado: The Nice Guys (290250) | Tempo: 27.14s
#
# --- Processando: V for Vendetta (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 752)...
# Adicionado: V for Vendetta (752) | Tempo: 27.37s
#
# --- Processando: Moneyball (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 60308)...
# Adicionado: Moneyball (60308) | Tempo: 27.60s
#
# --- Processando: Midnight in Paris (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 59436)...
# Adicionado: Midnight in Paris (59436) | Tempo: 27.84s
#
# --- Processando: The Imitation Game (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 205596)...
# Adicionado: The Imitation Game (205596) | Tempo: 28.07s
#
# --- Processando: The Incredible Hulk (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 1724)...
# Adicionado: The Incredible Hulk (1724) | Tempo: 28.30s
#
# --- Processando: Klaus (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 508965)...
# Adicionado: Klaus (508965) | Tempo: 28.54s
#
# --- Processando: Ford v Ferrari (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 359724)...
# Adicionado: Ford v Ferrari (359724) | Tempo: 28.77s
#
# --- Processando: Into the Wild (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 5915)...
# Adicionado: Into the Wild (5915) | Tempo: 29.01s
#
# --- Processando: Saw (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 176)...
# Adicionado: Saw (176) | Tempo: 29.24s
#
# --- Processando: Lilo & Stitch (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 11544)...
# Adicionado: Lilo & Stitch (11544) | Tempo: 29.48s
#
# --- Processando: Frozen II (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 330457)...
# Adicionado: Frozen II (330457) | Tempo: 29.76s
#
# --- Processando: A Silent Voice: The Movie (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 378064)...
# Adicionado: A Silent Voice: The Movie (378064) | Tempo: 29.99s
#
# --- Processando: The Intouchables (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 77338)...
# Adicionado: The Intouchables (77338) | Tempo: 30.22s
#
# --- Processando: Gangs of New York (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 3131)...
# Adicionado: Gangs of New York (3131) | Tempo: 30.46s
#
# --- Processando: O Brother, Where Art Thou? (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 134)...
# Adicionado: O Brother, Where Art Thou? (134) | Tempo: 30.73s
#
# --- Processando: The Machinist (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 4553)...
# Adicionado: The Machinist (4553) | Tempo: 30.96s
#
# --- Processando: Kick-Ass (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 23483)...
# Adicionado: Kick-Ass (23483) | Tempo: 31.20s
#
# --- Processando: Enola Holmes (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 497582)...
# Adicionado: Enola Holmes (497582) | Tempo: 31.43s
#
# --- Processando: The Boy in the Striped Pyjamas (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 14574)...
# Adicionado: The Boy in the Striped Pyjamas (14574) | Tempo: 31.66s
#
# --- Processando: The Butterfly Effect (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 1954)...
# Adicionado: The Butterfly Effect (1954) | Tempo: 31.90s
#
# --- Processando: Mission: Impossible (1996) ---
# Enviando requisição...
# Buscando detalhes (ID: 954)...
# Adicionado: Mission: Impossible (954) | Tempo: 32.14s
#
# --- Processando: Ocean's Twelve (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 163)...
# Adicionado: Ocean's Twelve (163) | Tempo: 32.37s
#
# --- Processando: District 9 (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 17654)...
# Adicionado: District 9 (17654) | Tempo: 32.61s
#
# --- Processando: Billy Elliot (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 71)...
# Adicionado: Billy Elliot (71) | Tempo: 32.84s
#
# --- Processando: The Blind Side (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 22881)...
# Adicionado: The Blind Side (22881) | Tempo: 33.07s
#
# --- Processando: Lion (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 334543)...
# Adicionado: Lion (334543) | Tempo: 33.31s
#
# --- Processando: Taken (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 8681)...
# Adicionado: Taken (8681) | Tempo: 33.55s
#
# --- Processando: A Dog's Will (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 40096)...
# Adicionado: A Dog's Will (40096) | Tempo: 33.79s
#
# --- Processando: Spirited Away (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 129)...
# Adicionado: Spirited Away (129) | Tempo: 34.02s
#
# --- Processando: Gonjiam: Haunted Asylum (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 508642)...
# Adicionado: Gonjiam: Haunted Asylum (508642) | Tempo: 34.25s
#
# --- Processando: Searching (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 489999)...
# Adicionado: Searching (489999) | Tempo: 34.49s
#
# --- Processando: To All the Boys I've Loved Before (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 466282)...
# Adicionado: To All the Boys I've Loved Before (466282) | Tempo: 34.73s
#
# --- Processando: Goodnight Mommy (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 284303)...
# Adicionado: Goodnight Mommy (284303) | Tempo: 34.96s
#
# --- Processando: The Platform (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 619264)...
# Adicionado: The Platform (619264) | Tempo: 35.24s
#
# --- Processando: Batman v Superman: Dawn of Justice (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 209112)...
# Adicionado: Batman v Superman: Dawn of Justice (209112) | Tempo: 35.48s
#
# --- Processando: As Good as It Gets (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 2898)...
# Adicionado: As Good as It Gets (2898) | Tempo: 35.71s
#
# --- Processando: Lock, Stock and Two Smoking Barrels (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 100)...
# Adicionado: Lock, Stock and Two Smoking Barrels (100) | Tempo: 35.94s
#
# --- Processando: Apt Pupil (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 9445)...
# Adicionado: Apt Pupil (9445) | Tempo: 36.18s
#
# --- Processando: He Got Game (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 9469)...
# Adicionado: He Got Game (9469) | Tempo: 36.41s
#
# --- Processando: Nine Queens (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 18079)...
# Adicionado: Nine Queens (18079) | Tempo: 36.68s
#
# --- Processando: Waking Life (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 9081)...
# Adicionado: Waking Life (9081) | Tempo: 36.92s
#
# --- Processando: Secret Window (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 1586)...
# Adicionado: Secret Window (1586) | Tempo: 37.15s
#
# --- Processando: Million Dollar Baby (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 70)...
# Adicionado: Million Dollar Baby (70) | Tempo: 37.38s
#
# --- Processando: Coach Carter (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 7214)...
# Adicionado: Coach Carter (7214) | Tempo: 37.62s
#
# --- Processando: Hachi: A Dog's Tale (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 28178)...
# Adicionado: Hachi: A Dog's Tale (28178) | Tempo: 37.85s
#
# --- Processando: Predestination (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 206487)...
# Adicionado: Predestination (206487) | Tempo: 38.12s
#
# --- Processando: Sing Street (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 369557)...
# Adicionado: Sing Street (369557) | Tempo: 38.35s
#
# --- Processando: The Man Who Knew Infinity (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 353326)...
# Adicionado: The Man Who Knew Infinity (353326) | Tempo: 38.58s
#
# --- Processando: Straight Outta Compton (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 277216)...
# Adicionado: Straight Outta Compton (277216) | Tempo: 38.85s
#
# --- Processando: The Italian Job (2003) ---
# Enviando requisição...
# Buscando detalhes (ID: 9654)...
# Adicionado: The Italian Job (9654) | Tempo: 39.08s
#
# --- Processando: I Killed My Mother (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 26280)...
# Adicionado: I Killed My Mother (26280) | Tempo: 39.32s
#
# --- Processando: The Babadook (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 242224)...
# Adicionado: The Babadook (242224) | Tempo: 39.55s
#
# --- Processando: Gerald's Game (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 343674)...
# Adicionado: Gerald's Game (343674) | Tempo: 39.79s
#
# --- Processando: As the Gods Will (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 241863)...
# Adicionado: As the Gods Will (241863) | Tempo: 40.08s
#
# --- Processando: Death Note (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 351460)...
# Adicionado: Death Note (351460) | Tempo: 40.31s
#
# --- Processando: Up (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 14160)...
# Adicionado: Up (14160) | Tempo: 40.55s
#
# --- Processando: Toy Story (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 862)...
# Adicionado: Toy Story (862) | Tempo: 40.78s
#
# --- Processando: Toy Story 2 (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 863)...
# Adicionado: Toy Story 2 (863) | Tempo: 41.01s
#
# --- Processando: The Incredibles (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 9806)...
# Adicionado: The Incredibles (9806) | Tempo: 41.24s
#
# --- Processando: CODA (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 776503)...
# Adicionado: CODA (776503) | Tempo: 41.47s
#
# --- Processando: tick, tick... BOOM! (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 537116)...
# Adicionado: tick, tick... BOOM! (537116) | Tempo: 41.71s
#
# --- Processando: The Green Knight (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 559907)...
# Adicionado: The Green Knight (559907) | Tempo: 41.94s
#
# --- Processando: The Humans (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 588367)...
# Adicionado: The Humans (588367) | Tempo: 42.19s
#
# --- Processando: Dear Evan Hansen (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 567690)...
# Adicionado: Dear Evan Hansen (567690) | Tempo: 42.42s
#
# --- Processando: King Richard (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 614917)...
# Adicionado: King Richard (614917) | Tempo: 42.65s
#
# --- Processando: Belfast (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 777270)...
# Adicionado: Belfast (777270) | Tempo: 42.89s
#
# --- Processando: The Last Duel (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 617653)...
# Adicionado: The Last Duel (617653) | Tempo: 43.12s
#
# --- Processando: The Harder They Fall (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 618162)...
# Adicionado: The Harder They Fall (618162) | Tempo: 43.36s
#
# --- Processando: Scarface (1932) ---
# Enviando requisição...
# Buscando detalhes (ID: 877)...
# Adicionado: Scarface (877) | Tempo: 43.59s
#
# --- Processando: Wolfwalkers (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 441130)...
# Adicionado: Wolfwalkers (441130) | Tempo: 43.83s
#
# --- Processando: Spider-Man: Far From Home (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 429617)...
# Adicionado: Spider-Man: Far From Home (429617) | Tempo: 44.06s
#
# --- Processando: Space Jam: A New Legacy (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 379686)...
# Adicionado: Space Jam: A New Legacy (379686) | Tempo: 44.30s
#
# --- Processando: Kingsman: The Golden Circle (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 343668)...
# Adicionado: Kingsman: The Golden Circle (343668) | Tempo: 44.53s
#
# --- Processando: Escape Room (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 522681)...
# Adicionado: Escape Room (522681) | Tempo: 44.76s
#
# --- Processando: Ron's Gone Wrong (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 482321)...
# Adicionado: Ron's Gone Wrong (482321) | Tempo: 44.99s
#
# --- Processando: West Side Story (1961) ---
# Enviando requisição...
# Buscando detalhes (ID: 1725)...
# Adicionado: West Side Story (1725) | Tempo: 45.23s
#
# --- Processando: Luca (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 508943)...
# Adicionado: Luca (508943) | Tempo: 45.46s
#
# --- Processando: Reservoir Dogs (1992) ---
# Enviando requisição...
# Buscando detalhes (ID: 500)...
# Adicionado: Reservoir Dogs (500) | Tempo: 45.69s
#
# --- Processando: Sing (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 335797)...
# Adicionado: Sing (335797) | Tempo: 45.94s
#
# --- Processando: Sing 2 (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 438695)...
# Adicionado: Sing 2 (438695) | Tempo: 46.17s
#
# --- Processando: E.T. the Extra-Terrestrial (1982) ---
# Enviando requisição...
# Buscando detalhes (ID: 601)...
# Adicionado: E.T. the Extra-Terrestrial (601) | Tempo: 46.40s
#
# --- Processando: A Hero (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 672208)...
# Adicionado: A Hero (672208) | Tempo: 46.65s
#
# --- Processando: Metamorphosis (1975) ---
# Enviando requisição...
# Buscando detalhes (ID: 553326)...
# Adicionado: Metamorphosis (553326) | Tempo: 46.89s
#
# --- Processando: Red Rocket (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 763329)...
# Adicionado: Red Rocket (763329) | Tempo: 47.12s
#
# --- Processando: Flee (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 680813)...
# Adicionado: Flee (680813) | Tempo: 47.36s
#
# --- Processando: West Side Story (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 511809)...
# Adicionado: West Side Story (511809) | Tempo: 47.60s
#
# --- Processando: Turning Red (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 508947)...
# Adicionado: Turning Red (508947) | Tempo: 47.83s
#
# --- Processando: Scream (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 646385)...
# Adicionado: Scream (646385) | Tempo: 48.07s
#
# --- Processando: Spider-Man: No Way Home (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 634649)...
# Adicionado: Spider-Man: No Way Home (634649) | Tempo: 48.30s
#
# --- Processando: House of Gucci (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 644495)...
# Adicionado: House of Gucci (644495) | Tempo: 48.54s
#
# --- Processando: 50/50 (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 40807)...
# Adicionado: 50/50 (40807) | Tempo: 48.77s
#
# --- Processando: Raging Bull (1980) ---
# Enviando requisição...
# Buscando detalhes (ID: 1578)...
# Adicionado: Raging Bull (1578) | Tempo: 49.01s
#
# --- Processando: The Hitchhiker's Guide to the Galaxy (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 7453)...
# Adicionado: The Hitchhiker's Guide to the Galaxy (7453) | Tempo: 49.24s
#
# --- Processando: Wanted (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 8909)...
# Adicionado: Wanted (8909) | Tempo: 49.48s
#
# --- Processando: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) ---
# Enviando requisição...
# Buscando detalhes (ID: 935)...
# Adicionado: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (935) | Tempo: 49.71s
#
# --- Processando: Nightmare Alley (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 597208)...
# Adicionado: Nightmare Alley (597208) | Tempo: 49.94s
#
# --- Processando: The Great Dictator (1940) ---
# Enviando requisição...
# Buscando detalhes (ID: 914)...
# Adicionado: The Great Dictator (914) | Tempo: 50.18s
#
# --- Processando: Mr. Thank You (1936) ---
# Enviando requisição...
# Buscando detalhes (ID: 100033)...
# Adicionado: Mr. Thank You (100033) | Tempo: 50.41s
#
# --- Processando: 3-Iron (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 1280)...
# Adicionado: 3-Iron (1280) | Tempo: 50.65s
#
# --- Processando: Infernal Affairs (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 10775)...
# Adicionado: Infernal Affairs (10775) | Tempo: 50.88s
#
# --- Processando: Parallel Mothers (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 766798)...
# Adicionado: Parallel Mothers (766798) | Tempo: 51.12s
#
# --- Processando: The Departed (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 1422)...
# Adicionado: The Departed (1422) | Tempo: 51.36s
#
# --- Processando: Taxi Driver (1976) ---
# Enviando requisição...
# Buscando detalhes (ID: 103)...
# Adicionado: Taxi Driver (103) | Tempo: 51.59s
#
# --- Processando: The Bad Guys (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 629542)...
# Adicionado: The Bad Guys (629542) | Tempo: 51.82s
#
# --- Processando: Fargo (1996) ---
# Enviando requisição...
# Buscando detalhes (ID: 275)...
# Adicionado: Fargo (275) | Tempo: 52.06s
#
# --- Processando: Marley & Me (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 14306)...
# Adicionado: Marley & Me (14306) | Tempo: 52.29s
#
# --- Processando: Flags of Our Fathers (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 3683)...
# Adicionado: Flags of Our Fathers (3683) | Tempo: 52.53s
#
# --- Processando: Petite Maman (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 749004)...
# Adicionado: Petite Maman (749004) | Tempo: 52.77s
#
# --- Processando: Letters from Iwo Jima (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 1251)...
# Adicionado: Letters from Iwo Jima (1251) | Tempo: 53.00s
#
# --- Processando: The Big Lebowski (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 115)...
# Adicionado: The Big Lebowski (115) | Tempo: 53.24s
#
# --- Processando: The Seventh Seal (1957) ---
# Enviando requisição...
# Buscando detalhes (ID: 490)...
# Adicionado: The Seventh Seal (490) | Tempo: 53.47s
#
# --- Processando: One Night in Miami... (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 661914)...
# Adicionado: One Night in Miami... (661914) | Tempo: 53.75s
#
# --- Processando: A Fistful of Dollars (1964) ---
# Enviando requisição...
# Buscando detalhes (ID: 391)...
# Adicionado: A Fistful of Dollars (391) | Tempo: 53.98s
#
# --- Processando: For a Few Dollars More (1965) ---
# Enviando requisição...
# Buscando detalhes (ID: 938)...
# Adicionado: For a Few Dollars More (938) | Tempo: 54.22s
#
# --- Processando: One Flew Over the Cuckoo's Nest (1975) ---
# Enviando requisição...
# Buscando detalhes (ID: 510)...
# Adicionado: One Flew Over the Cuckoo's Nest (510) | Tempo: 54.45s
#
# --- Processando: The Good, the Bad and the Ugly (1966) ---
# Enviando requisição...
# Buscando detalhes (ID: 429)...
# Adicionado: The Good, the Bad and the Ugly (429) | Tempo: 54.69s
#
# --- Processando: The Lure (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 375742)...
# Adicionado: The Lure (375742) | Tempo: 54.92s
#
# --- Processando: The Last Picture Show (1971) ---
# Enviando requisição...
# Buscando detalhes (ID: 25188)...
# Adicionado: The Last Picture Show (25188) | Tempo: 55.16s
#
# --- Processando: 10 Cloverfield Lane (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 333371)...
# Adicionado: 10 Cloverfield Lane (333371) | Tempo: 55.39s
#
# --- Processando: The Northman (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 639933)...
# Adicionado: The Northman (639933) | Tempo: 55.63s
#
# --- Processando: How to Train Your Dragon (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 10191)...
# Adicionado: How to Train Your Dragon (10191) | Tempo: 55.86s
#
# --- Processando: How to Train Your Dragon 2 (2014) ---
# Enviando requisição...
# Buscando detalhes (ID: 82702)...
# Adicionado: How to Train Your Dragon 2 (82702) | Tempo: 56.09s
#
# --- Processando: How to Train Your Dragon: The Hidden World (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 166428)...
# Adicionado: How to Train Your Dragon: The Hidden World (166428) | Tempo: 56.33s
#
# --- Processando: War of the Worlds (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 74)...
# Adicionado: War of the Worlds (74) | Tempo: 56.57s
#
# --- Processando: The Unbearable Weight of Massive Talent (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 648579)...
# Adicionado: The Unbearable Weight of Massive Talent (648579) | Tempo: 56.80s
#
# --- Processando: Au Revoir les Enfants (1987) ---
# Enviando requisição...
# Buscando detalhes (ID: 1786)...
# Adicionado: Au Revoir les Enfants (1786) | Tempo: 57.04s
#
# --- Processando: Homunculus (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 741434)...
# Adicionado: Homunculus (741434) | Tempo: 57.27s
#
# --- Processando: The Salesman (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 375315)...
# Adicionado: The Salesman (375315) | Tempo: 57.50s
#
# --- Processando: Amores Perros (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 55)...
# Adicionado: Amores Perros (55) | Tempo: 57.74s
#
# --- Processando: Belladonna of Sadness (1973) ---
# Enviando requisição...
# Buscando detalhes (ID: 64847)...
# Adicionado: Belladonna of Sadness (64847) | Tempo: 57.97s
#
# --- Processando: Mulholland Drive (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 1018)...
# Adicionado: Mulholland Drive (1018) | Tempo: 58.20s
#
# --- Processando: Crimes of the Future (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 819876)...
# Adicionado: Crimes of the Future (819876) | Tempo: 58.44s
#
# --- Processando: Catch Me If You Can (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 640)...
# Adicionado: Catch Me If You Can (640) | Tempo: 58.67s
#
# --- Processando: The Virgin Suicides (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 1443)...
# Adicionado: The Virgin Suicides (1443) | Tempo: 58.90s
#
# --- Processando: Prisoners (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 146233)...
# Adicionado: Prisoners (146233) | Tempo: 59.13s
#
# --- Processando: RRR (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 579974)...
# Adicionado: RRR (579974) | Tempo: 59.37s
#
# --- Processando: Eternal Sunshine of the Spotless Mind (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 38)...
# Adicionado: Eternal Sunshine of the Spotless Mind (38) | Tempo: 59.60s
#
# --- Processando: Day Shift (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 755566)...
# Adicionado: Day Shift (755566) | Tempo: 59.84s
#
# --- Processando: Prey (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 766507)...
# Adicionado: Prey (766507) | Tempo: 60.08s
#
# --- Processando: Hiroshima Mon Amour (1959) ---
# Enviando requisição...
# Buscando detalhes (ID: 5544)...
# Adicionado: Hiroshima Mon Amour (5544) | Tempo: 60.31s
#
# --- Processando: 1987: When the Day Comes (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 437103)...
# Adicionado: 1987: When the Day Comes (437103) | Tempo: 60.54s
#
# --- Processando: Happy Together (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 18329)...
# Adicionado: Happy Together (18329) | Tempo: 60.78s
#
# --- Processando: The Thing (1982) ---
# Enviando requisição...
# Buscando detalhes (ID: 1091)...
# Adicionado: The Thing (1091) | Tempo: 61.02s
#
# --- Processando: Argentina 1985 (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 714888)...
# Adicionado: Argentina 1985 (714888) | Tempo: 61.30s
#
# --- Processando: Lola (1981) ---
# Enviando requisição...
# Buscando detalhes (ID: 2264)...
# Adicionado: Lola (2264) | Tempo: 61.53s
#
# --- Processando: Stray Dog (1949) ---
# Enviando requisição...
# Buscando detalhes (ID: 30368)...
# Adicionado: Stray Dog (30368) | Tempo: 61.77s
#
# --- Processando: Pickpocket (1959) ---
# Enviando requisição...
# Buscando detalhes (ID: 690)...
# Adicionado: Pickpocket (690) | Tempo: 62.00s
#
# --- Processando: Repulsion (1965) ---
# Enviando requisição...
# Buscando detalhes (ID: 11481)...
# Adicionado: Repulsion (11481) | Tempo: 62.24s
#
# --- Processando: Don't Worry Darling (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 619730)...
# Adicionado: Don't Worry Darling (619730) | Tempo: 62.47s
#
# --- Processando: Jeanne Dielman, 23, quai du Commerce, 1080 Bruxelles (1975) ---
# Enviando requisição...
# Buscando detalhes (ID: 44012)...
# Adicionado: Jeanne Dielman, 23, quai du Commerce, 1080 Bruxelles (44012) | Tempo: 62.71s
#
# --- Processando: Mishima: A Life in Four Chapters (1985) ---
# Enviando requisição...
# Buscando detalhes (ID: 27064)...
# Adicionado: Mishima: A Life in Four Chapters (27064) | Tempo: 62.94s
#
# --- Processando: 4 Months, 3 Weeks and 2 Days (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 2009)...
# Adicionado: 4 Months, 3 Weeks and 2 Days (2009) | Tempo: 63.17s
#
# --- Processando: An Angel at My Table (1990) ---
# Enviando requisição...
# Buscando detalhes (ID: 2891)...
# Adicionado: An Angel at My Table (2891) | Tempo: 63.41s
#
# --- Processando: A Brighter Summer Day (1991) ---
# Enviando requisição...
# Buscando detalhes (ID: 15804)...
# Adicionado: A Brighter Summer Day (15804) | Tempo: 63.64s
#
# --- Processando: Secret Sunshine (2007) ---
# Enviando requisição...
# Buscando detalhes (ID: 2015)...
# Adicionado: Secret Sunshine (2015) | Tempo: 63.88s
#
# --- Processando: Still Walking (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 25050)...
# Adicionado: Still Walking (25050) | Tempo: 64.12s
#
# --- Processando: Shoplifters (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 505192)...
# Adicionado: Shoplifters (505192) | Tempo: 64.35s
#
# --- Processando: Broker (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 736732)...
# Adicionado: Broker (736732) | Tempo: 64.59s
#
# --- Processando: Nobody Knows (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 2517)...
# Adicionado: Nobody Knows (2517) | Tempo: 64.82s
#
# --- Processando: The Terminal (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 594)...
# Adicionado: The Terminal (594) | Tempo: 65.09s
#
# --- Processando: Titane (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 630240)...
# Adicionado: Titane (630240) | Tempo: 65.32s
#
# --- Processando: C'mon C'mon (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 632617)...
# Adicionado: C'mon C'mon (632617) | Tempo: 65.56s
#
# --- Processando: American History X (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 73)...
# Adicionado: American History X (73) | Tempo: 65.79s
#
# --- Processando: Sympathy for Mr. Vengeance (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 4689)...
# Adicionado: Sympathy for Mr. Vengeance (4689) | Tempo: 66.02s
#
# --- Processando: Lady Vengeance (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 4550)...
# Adicionado: Lady Vengeance (4550) | Tempo: 66.26s
#
# --- Processando: Three Thousand Years of Longing (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 556694)...
# Adicionado: Three Thousand Years of Longing (556694) | Tempo: 66.49s
#
# --- Processando: Burning (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 813106)...
# Adicionado: Burning (813106) | Tempo: 66.73s
#
# --- Processando: American Beauty (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 14)...
# Adicionado: American Beauty (14) | Tempo: 66.96s
#
# --- Processando: Respect (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 592863)...
# Adicionado: Respect (592863) | Tempo: 67.20s
#
# --- Processando: The Amazing Spider-Man (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 1930)...
# Adicionado: The Amazing Spider-Man (1930) | Tempo: 67.43s
#
# --- Processando: Fear Street: 1978 (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 591274)...
# Adicionado: Fear Street: 1978 (591274) | Tempo: 67.66s
#
# --- Processando: Fear Street: 1994 (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 591273)...
# Adicionado: Fear Street: 1994 (591273) | Tempo: 67.90s
#
# --- Processando: The Tender Bar (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 727293)...
# Adicionado: The Tender Bar (727293) | Tempo: 68.13s
#
# --- Processando: Joint Security Area (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 2440)...
# Adicionado: Joint Security Area (2440) | Tempo: 68.37s
#
# --- Processando: After Life (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 17962)...
# Adicionado: After Life (17962) | Tempo: 68.61s
#
# --- Processando: Thirst (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 22536)...
# Adicionado: Thirst (22536) | Tempo: 68.84s
#
# --- Processando: All Quiet on the Western Front (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 49046)...
# Adicionado: All Quiet on the Western Front (49046) | Tempo: 69.08s
#
# --- Processando: Puss in Boots: The Last Wish (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 315162)...
# Adicionado: Puss in Boots: The Last Wish (315162) | Tempo: 69.32s
#
# --- Processando: Aftersun (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 965150)...
# Adicionado: Aftersun (965150) | Tempo: 69.55s
#
# --- Processando: Poetry (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 47909)...
# Adicionado: Poetry (47909) | Tempo: 69.79s
#
# --- Processando: I'm a Cyborg, But That's OK (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 5488)...
# Adicionado: I'm a Cyborg, But That's OK (5488) | Tempo: 70.02s
#
# --- Processando: Stoker (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 86825)...
# Adicionado: Stoker (86825) | Tempo: 70.25s
#
# --- Processando: Mulan (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 10674)...
# Adicionado: Mulan (10674) | Tempo: 70.48s
#
# --- Processando: The Quiet Girl (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 916405)...
# Adicionado: The Quiet Girl (916405) | Tempo: 70.71s
#
# --- Processando: Okja (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 387426)...
# Adicionado: Okja (387426) | Tempo: 70.95s
#
# --- Processando: The Host (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 1255)...
# Adicionado: The Host (1255) | Tempo: 71.19s
#
# --- Processando: Mother (2009) ---
# Enviando requisição...
# Buscando detalhes (ID: 698885)...
# Adicionado: Mother (698885) | Tempo: 71.43s
#
# --- Processando: We're All Going to the World's Fair (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 776501)...
# Adicionado: We're All Going to the World's Fair (776501) | Tempo: 71.66s
#
# --- Processando: 20th Century Girl (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 851644)...
# Adicionado: 20th Century Girl (851644) | Tempo: 71.90s
#
# --- Processando: Happening (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 793998)...
# Adicionado: Happening (793998) | Tempo: 72.14s
#
# --- Processando: Nanny (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 843932)...
# Adicionado: Nanny (843932) | Tempo: 72.38s
#
# --- Processando: The Help (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 50014)...
# Adicionado: The Help (50014) | Tempo: 72.65s
#
# --- Processando: Entergalactic (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 1027014)...
# Adicionado: Entergalactic (1027014) | Tempo: 72.88s
#
# --- Processando: Inu-Oh (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 642538)...
# Adicionado: Inu-Oh (642538) | Tempo: 73.11s
#
# --- Processando: Frances Ha (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 121986)...
# Adicionado: Frances Ha (121986) | Tempo: 73.35s
#
# --- Processando: Space Is the Place (1974) ---
# Enviando requisição...
# Buscando detalhes (ID: 16203)...
# Adicionado: Space Is the Place (16203) | Tempo: 73.58s
#
# --- Processando: Roma (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 426426)...
# Adicionado: Roma (426426) | Tempo: 73.82s
#
# --- Processando: Mars One (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 913816)...
# Adicionado: Mars One (913816) | Tempo: 74.06s
#
# --- Processando: Mister Johnson (1990) ---
# Enviando requisição...
# Buscando detalhes (ID: 123772)...
# Adicionado: Mister Johnson (123772) | Tempo: 74.29s
#
# --- Processando: The Girls (1968) ---
# Enviando requisição...
# Buscando detalhes (ID: 135337)...
# Adicionado: The Girls (135337) | Tempo: 74.53s
#
# --- Processando: Before Sunrise (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 76)...
# Adicionado: Before Sunrise (76) | Tempo: 74.76s
#
# ...
# Buscando detalhes (ID: 9003)...
# Adicionado: Hellraiser (9003) | Tempo: 166.30s
#
# --- Processando: Prometheus (2012) ---
# Enviando requisição...
# Buscando detalhes (ID: 70981)...
# Adicionado: Prometheus (70981) | Tempo: 166.53s
#
# --- Processando: Deep Red (1975) ---
# Enviando requisição...
# Buscando detalhes (ID: 20126)...
# Adicionado: Deep Red (20126) | Tempo: 166.76s
#
# --- Processando: Ilo Ilo (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 188598)...
# Adicionado: Ilo Ilo (188598) | Tempo: 167.00s
#
# --- Processando: Bulbbul (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 714338)...
# Adicionado: Bulbbul (714338) | Tempo: 167.23s
#
# --- Processando: Inferno (1980) ---
# Enviando requisição...
# Buscando detalhes (ID: 16395)...
# Adicionado: Inferno (16395) | Tempo: 167.46s
#
# --- Processando: The Beyond (1981) ---
# Enviando requisição...
# Buscando detalhes (ID: 19204)...
# Adicionado: The Beyond (19204) | Tempo: 167.70s
#
# --- Processando: The Stuff (1985) ---
# Enviando requisição...
# Buscando detalhes (ID: 18502)...
# Adicionado: The Stuff (18502) | Tempo: 167.93s
#
# --- Processando: Concrete Utopia (2023) ---
# Enviando requisição...
# Buscando detalhes (ID: 729854)...
# Adicionado: Concrete Utopia (729854) | Tempo: 168.17s
#
# --- Processando: Guilty of Romance (2011) ---
# Enviando requisição...
# Buscando detalhes (ID: 80662)...
# Adicionado: Guilty of Romance (80662) | Tempo: 168.40s
#
# --- Processando: The Love Witch (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 374052)...
# Adicionado: The Love Witch (374052) | Tempo: 168.63s
#
# --- Processando: Alien: Covenant (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 126889)...
# Adicionado: Alien: Covenant (126889) | Tempo: 168.87s
#
# --- Processando: Alien: Romulus (2024) ---
# Enviando requisição...
# Buscando detalhes (ID: 945961)...
# Adicionado: Alien: Romulus (945961) | Tempo: 169.10s
#
# --- Processando: The Quiet Family (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 74336)...
# Adicionado: The Quiet Family (74336) | Tempo: 169.34s
#
# --- Processando: Little Monsters (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 503125)...
# Adicionado: Little Monsters (503125) | Tempo: 169.57s
#
# --- Processando: Piranha (1978) ---
# Enviando requisição...
# Buscando detalhes (ID: 24831)...
# Adicionado: Piranha (24831) | Tempo: 169.81s
#
# --- Processando: Dawn of the Dead (1978) ---
# Enviando requisição...
# Buscando detalhes (ID: 923)...
# Adicionado: Dawn of the Dead (923) | Tempo: 170.04s
#
# --- Processando: Whispering Corridors (1998) ---
# Enviando requisição...
# Buscando detalhes (ID: 40254)...
# Adicionado: Whispering Corridors (40254) | Tempo: 170.28s
#
# --- Processando: Memento Mori (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 54111)...
# Adicionado: Memento Mori (54111) | Tempo: 170.51s
#
# --- Processando: Fireworks (1997) ---
# Enviando requisição...
# Buscando detalhes (ID: 5910)...
# Adicionado: Fireworks (5910) | Tempo: 170.75s
#
# --- Processando: Eyes Without a Face (1960) ---
# Enviando requisição...
# Buscando detalhes (ID: 31417)...
# Adicionado: Eyes Without a Face (31417) | Tempo: 170.98s
#
# --- Processando: The Wicker Man (1973) ---
# Enviando requisição...
# Buscando detalhes (ID: 16307)...
# Adicionado: The Wicker Man (16307) | Tempo: 171.22s
#
# --- Processando: Stage Fright (1987) ---
# Enviando requisição...
# Buscando detalhes (ID: 20465)...
# Adicionado: Stage Fright (20465) | Tempo: 171.45s
#
# --- Processando: Rats: Night of Terror (1984) ---
# Enviando requisição...
# Buscando detalhes (ID: 83223)...
# Adicionado: Rats: Night of Terror (83223) | Tempo: 171.69s
#
# --- Processando: New Nightmare (1994) ---
# Enviando requisição...
# Buscando detalhes (ID: 11596)...
# Adicionado: New Nightmare (11596) | Tempo: 171.92s
#
# --- Processando: The Phantom Carriage (1921) ---
# Enviando requisição...
# Buscando detalhes (ID: 58129)...
# Adicionado: The Phantom Carriage (58129) | Tempo: 172.15s
#
# --- Processando: Paprika (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 4977)...
# Adicionado: Paprika (4977) | Tempo: 172.39s
#
# --- Processando: Nausicaä of the Valley of the Wind (1984) ---
# Enviando requisição...
# Buscando detalhes (ID: 81)...
# Adicionado: Nausicaä of the Valley of the Wind (81) | Tempo: 172.62s
#
# --- Processando: Seven Samurai (1954) ---
# Enviando requisição...
# Buscando detalhes (ID: 346)...
# Adicionado: Seven Samurai (346) | Tempo: 172.86s
#
# --- Processando: Spider-Man (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 557)...
# Adicionado: Spider-Man (557) | Tempo: 173.09s
#
# --- Processando: Le Samouraï (1967) ---
# Enviando requisição...
# Buscando detalhes (ID: 5511)...
# Adicionado: Le Samouraï (5511) | Tempo: 173.32s
#
# --- Processando: Johanna d‘Arc of Mongolia (1989) ---
# Enviando requisição...
# Buscando detalhes (ID: 120268)...
# Adicionado: Johanna d‘Arc of Mongolia (120268) | Tempo: 173.56s
#
# --- Processando: Rashomon (1950) ---
# Enviando requisição...
# Buscando detalhes (ID: 548)...
# Adicionado: Rashomon (548) | Tempo: 173.79s
#
# --- Processando: Z (1969) ---
# Enviando requisição...
# Buscando detalhes (ID: 2721)...
# Adicionado: Z (2721) | Tempo: 174.03s
#
# --- Processando: Battleship Potemkin (1925) ---
# Enviando requisição...
# Buscando detalhes (ID: 643)...
# Adicionado: Battleship Potemkin (643) | Tempo: 174.27s
#
# --- Processando: Touki Bouki (1973) ---
# Enviando requisição...
# Buscando detalhes (ID: 77771)...
# Adicionado: Touki Bouki (77771) | Tempo: 174.50s
#
# --- Processando: Love for Sale (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 95342)...
# Adicionado: Love for Sale (95342) | Tempo: 174.74s
#
# --- Processando: Lady Snowblood (1973) ---
# Enviando requisição...
# Buscando detalhes (ID: 2487)...
# Adicionado: Lady Snowblood (2487) | Tempo: 174.97s
#
# --- Processando: The Battle of Algiers (1966) ---
# Enviando requisição...
# Buscando detalhes (ID: 17295)...
# Adicionado: The Battle of Algiers (17295) | Tempo: 175.21s
#
# --- Processando: In This Corner of the World (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 378108)...
# Adicionado: In This Corner of the World (378108) | Tempo: 175.44s
#
# --- Processando: Home Alone 2: Lost in New York (1992) ---
# Enviando requisição...
# Buscando detalhes (ID: 772)...
# Adicionado: Home Alone 2: Lost in New York (772) | Tempo: 175.67s
#
# --- Processando: A Taste of Honey (1961) ---
# Enviando requisição...
# Buscando detalhes (ID: 25062)...
# Adicionado: A Taste of Honey (25062) | Tempo: 175.91s
#
# --- Processando: In the Heights (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 467909)...
# Adicionado: In the Heights (467909) | Tempo: 176.14s
#
# --- Processando: The Day I Met You (2023) ---
# Enviando requisição...
# Buscando detalhes (ID: 1176508)...
# Adicionado: The Day I Met You (1176508) | Tempo: 176.38s
#
# --- Processando: To Live (1994) ---
# Enviando requisição...
# Buscando detalhes (ID: 31439)...
# Adicionado: To Live (31439) | Tempo: 176.62s
#
# --- Processando: Thief (1981) ---
# Enviando requisição...
# Buscando detalhes (ID: 11524)...
# Adicionado: Thief (11524) | Tempo: 176.85s
#
# --- Processando: The Big Boss (1971) ---
# Enviando requisição...
# Buscando detalhes (ID: 12481)...
# Adicionado: The Big Boss (12481) | Tempo: 177.09s
#
# --- Processando: The Killer (1989) ---
# Enviando requisição...
# Buscando detalhes (ID: 10835)...
# Adicionado: The Killer (10835) | Tempo: 177.32s
#
# --- Processando: Hard Boiled (1992) ---
# Enviando requisição...
# Buscando detalhes (ID: 11782)...
# Adicionado: Hard Boiled (11782) | Tempo: 177.56s
#
# --- Processando: Candyman (1992) ---
# Enviando requisição...
# Buscando detalhes (ID: 9529)...
# Adicionado: Candyman (9529) | Tempo: 177.79s
#
# --- Processando: The Bridges of Madison County (1995) ---
# Enviando requisição...
# Buscando detalhes (ID: 688)...
# Adicionado: The Bridges of Madison County (688) | Tempo: 178.03s
#
# --- Processando: Suicide Club (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 12720)...
# Adicionado: Suicide Club (12720) | Tempo: 178.26s
#
# --- Processando: Bone Tomahawk (2015) ---
# Enviando requisição...
# Buscando detalhes (ID: 294963)...
# Adicionado: Bone Tomahawk (294963) | Tempo: 178.50s
#
# --- Processando: The Housemaid (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 45202)...
# Adicionado: The Housemaid (45202) | Tempo: 178.74s
#
# --- Processando: Anora (2024) ---
# Enviando requisição...
# Buscando detalhes (ID: 1064213)...
# Adicionado: Anora (1064213) | Tempo: 178.97s
#
# --- Processando: Shaolin Soccer (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 11770)...
# Adicionado: Shaolin Soccer (11770) | Tempo: 179.21s
#
# --- Processando: Peppermint Candy (1999) ---
# Enviando requisição...
# Buscando detalhes (ID: 41245)...
# Adicionado: Peppermint Candy (41245) | Tempo: 179.44s
#
# --- Processando: Bright (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 400106)...
# Adicionado: Bright (400106) | Tempo: 179.68s
#
# --- Processando: Insomnia (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 320)...
# Adicionado: Insomnia (320) | Tempo: 179.91s
#
# --- Processando: Her (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 152601)...
# Adicionado: Her (152601) | Tempo: 180.15s
#
# --- Processando: Over the Hedge (2006) ---
# Enviando requisição...
# Buscando detalhes (ID: 7518)...
# Adicionado: Over the Hedge (7518) | Tempo: 180.38s
#
# --- Processando: Passengers (2016) ---
# Enviando requisição...
# Buscando detalhes (ID: 274870)...
# Adicionado: Passengers (274870) | Tempo: 180.62s
#
# --- Processando: Aquaman (2018) ---
# Enviando requisição...
# Buscando detalhes (ID: 297802)...
# Adicionado: Aquaman (297802) | Tempo: 180.85s
#
# --- Processando: Dead Ringers (1988) ---
# Enviando requisição...
# Buscando detalhes (ID: 9540)...
# Adicionado: Dead Ringers (9540) | Tempo: 181.09s
#
# --- Processando: Past Lives (2023) ---
# Enviando requisição...
# Buscando detalhes (ID: 666277)...
# Adicionado: Past Lives (666277) | Tempo: 181.32s
#
# --- Processando: White Dog (1982) ---
# Enviando requisição...
# Buscando detalhes (ID: 47955)...
# Adicionado: White Dog (47955) | Tempo: 181.56s
#
# --- Processando: Requiem for a Dream (2000) ---
# Enviando requisição...
# Buscando detalhes (ID: 641)...
# Adicionado: Requiem for a Dream (641) | Tempo: 181.79s
#
# --- Processando: Slumdog Millionaire (2008) ---
# Enviando requisição...
# Buscando detalhes (ID: 12405)...
# Adicionado: Slumdog Millionaire (12405) | Tempo: 182.03s
#
# --- Processando: Pearl (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 949423)...
# Adicionado: Pearl (949423) | Tempo: 182.26s
#
# --- Processando: Lightyear (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 718789)...
# Adicionado: Lightyear (718789) | Tempo: 182.50s
#
# --- Processando: AVP: Alien vs. Predator (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 395)...
# Adicionado: AVP: Alien vs. Predator (395) | Tempo: 182.73s
#
# --- Processando: Soylent Green (1973) ---
# Enviando requisição...
# Buscando detalhes (ID: 12101)...
# Adicionado: Soylent Green (12101) | Tempo: 182.96s
#
# --- Processando: Snowpiercer (2013) ---
# Enviando requisição...
# Buscando detalhes (ID: 110415)...
# Adicionado: Snowpiercer (110415) | Tempo: 183.19s
#
# --- Processando: Charlie and the Chocolate Factory (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 118)...
# Adicionado: Charlie and the Chocolate Factory (118) | Tempo: 183.43s
#
# --- Processando: Charade (1963) ---
# Enviando requisição...
# Buscando detalhes (ID: 4808)...
# Adicionado: Charade (4808) | Tempo: 183.67s
#
# --- Processando: Don't Look Up (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 646380)...
# Adicionado: Don't Look Up (646380) | Tempo: 183.90s
#
# --- Processando: Women Talking (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 777245)...
# Adicionado: Women Talking (777245) | Tempo: 184.13s
#
# --- Processando: Matilda (1996) ---
# Enviando requisição...
# Buscando detalhes (ID: 10830)...
# Adicionado: Matilda (10830) | Tempo: 184.41s
#
# --- Processando: X (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 760104)...
# Adicionado: X (760104) | Tempo: 184.65s
#
# --- Processando: Raya and the Last Dragon (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 527774)...
# Adicionado: Raya and the Last Dragon (527774) | Tempo: 184.88s
#
# --- Processando: 2046 (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 844)...
# Adicionado: 2046 (844) | Tempo: 185.12s
#
# --- Processando: The Power of the Dog (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 600583)...
# Adicionado: The Power of the Dog (600583) | Tempo: 185.35s
#
# --- Processando: Get Rich or Die Tryin' (2005) ---
# Enviando requisição...
# Buscando detalhes (ID: 10060)...
# Adicionado: Get Rich or Die Tryin' (10060) | Tempo: 185.58s
#
# --- Processando: Rosemary's Baby (1968) ---
# Enviando requisição...
# Buscando detalhes (ID: 805)...
# Adicionado: Rosemary's Baby (805) | Tempo: 185.81s
#
# --- Processando: The Devil's Backbone (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 1433)...
# Adicionado: The Devil's Backbone (1433) | Tempo: 186.05s
#
# --- Processando: Y Tu Mamá También (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 1391)...
# Adicionado: Y Tu Mamá También (1391) | Tempo: 186.28s
#
# --- Processando: Stealing Raden Saleh (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 832544)...
# Adicionado: Stealing Raden Saleh (832544) | Tempo: 186.51s
#
# --- Processando: Spencer (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 716612)...
# Adicionado: Spencer (716612) | Tempo: 186.74s
#
# --- Processando: The Black Phone (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 756999)...
# Adicionado: The Black Phone (756999) | Tempo: 186.98s
#
# --- Processando: Logan (2017) ---
# Enviando requisição...
# Buscando detalhes (ID: 263115)...
# Adicionado: Logan (263115) | Tempo: 187.21s
#
# --- Processando: Worth (2020) ---
# Enviando requisição...
# Buscando detalhes (ID: 649394)...
# Adicionado: Worth (649394) | Tempo: 187.45s
#
# --- Processando: Being the Ricardos (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 517088)...
# Adicionado: Being the Ricardos (517088) | Tempo: 187.68s
#
# --- Processando: Jules and Jim (1962) ---
# Enviando requisição...
# Buscando detalhes (ID: 1628)...
# Adicionado: Jules and Jim (1628) | Tempo: 187.91s
#
# --- Processando: The Suicide Squad (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 436969)...
# Adicionado: The Suicide Squad (436969) | Tempo: 188.15s
#
# --- Processando: 8 Mile (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 65)...
# Adicionado: 8 Mile (65) | Tempo: 188.38s
#
# --- Processando: Marcel the Shell with Shoes On (2021) ---
# Enviando requisição...
# Buscando detalhes (ID: 869626)...
# Adicionado: Marcel the Shell with Shoes On (869626) | Tempo: 188.61s
#
# --- Processando: Sound of Metal (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 502033)...
# Adicionado: Sound of Metal (502033) | Tempo: 188.85s
#
# --- Processando: Merry Christmas, Mr. Lawrence (1983) ---
# Enviando requisição...
# Buscando detalhes (ID: 11948)...
# Adicionado: Merry Christmas, Mr. Lawrence (11948) | Tempo: 189.08s
#
# --- Processando: Daisies (1966) ---
# Enviando requisição...
# Buscando detalhes (ID: 46919)...
# Adicionado: Daisies (46919) | Tempo: 189.31s
#
# --- Processando: Dawn of the Dead (2004) ---
# Enviando requisição...
# Buscando detalhes (ID: 924)...
# Adicionado: Dawn of the Dead (924) | Tempo: 189.55s
#
# --- Processando: Oasis (2002) ---
# Enviando requisição...
# Buscando detalhes (ID: 26955)...
# Adicionado: Oasis (26955) | Tempo: 189.78s
#
# --- Processando: Bedevilled (2010) ---
# Enviando requisição...
# Buscando detalhes (ID: 59421)...
# Adicionado: Bedevilled (59421) | Tempo: 190.02s
#
# --- Processando: Gosford Park (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 5279)...
# Adicionado: Gosford Park (5279) | Tempo: 190.25s
#
# --- Processando: Furie (2019) ---
# Enviando requisição...
# Buscando detalhes (ID: 622654)...
# Adicionado: Get In (622654) | Tempo: 190.48s
#
# --- Processando: Furies (2022) ---
# Enviando requisição...
# Buscando detalhes (ID: 988667)...
# Adicionado: Furies (988667) | Tempo: 190.72s
#
# --- Processando: The Fast and the Furious (2001) ---
# Enviando requisição...
# Buscando detalhes (ID: 9799)...
# Adicionado: The Fast and the Furious (9799) | Tempo: 190.95s
#
# Total original: 809
# Total encontrado: 806
#
# Resultado final: 806 registros
# Tempo total: 190.96s

# %%
# Colocando a coluna minhas_notas e ano no dataframe tmdb
for i,filme in my_rating_df.iterrows():
    nome_f = filme['Name']
    nota = filme['Rating']
    ano = filme['Year']
    if nome_f in tmdb_rating_df['title'].values:
        tmdb_rating_df.loc[tmdb_rating_df['title'] == nome_f,'year'] = ano
        tmdb_rating_df.loc[tmdb_rating_df['title'] == nome_f,'minhas_notas'] = nota

# %%
# Salvando em um arquivo csv para não precisar refazer a busca
tmdb_rating_df.to_csv('my_movies_tmdb.csv', index=False)

# %%
tmdb_rating_df = pd.read_csv('my_movies_tmdb.csv')

# %%
tmdb_rating_df.head()
# Out:
#                          title  tmdb_id                   tmdb_title  year  \
# 0                       Violet   665901                       Violet  2021
# 1                     Hot Fuzz     4638                     Hot Fuzz  2007
# 2              The World's End   107985              The World's End  2013
# 3  Scott Pilgrim vs. the World    22538  Scott Pilgrim vs. the World  2010
# 4                   La La Land   313369                   La La Land  2016
#
#                 genre_ids original_language  popularity  vote_count  \
# 0                    [18]                en       1.025          25
# 1            [80, 28, 35]                en       5.328        7691
# 2           [35, 28, 878]                en       4.319        5473
# 3         [28, 35, 10749]                en       8.117        7993
# 4  [35, 18, 10749, 10402]                en      12.232       17121
#
#    vote_average    budget    revenue  runtime  production_company_id  \
# 0         7.000         0          0       92                20443.0
# 1         7.562  12000000   80600000      121                  443.0
# 2         6.807  20000000   46100000      109                  443.0
# 3         7.491  85000000   51691156      113                 2527.0
# 4         7.900  30000000  509183536      129                  491.0
#
#    minhas_notas
# 0           4.0
# 1           3.5
# 2           3.0
# 3           4.0
# 4           3.0

# %%
tmdb_rating_df.isnull().sum() # Verificando se tem valores vazios
# Out:
# title                    0
# tmdb_id                  0
# tmdb_title               0
# year                     0
# genre_ids                0
# original_language        0
# popularity               0
# vote_count               0
# vote_average             0
# budget                   0
# revenue                  0
# runtime                  0
# production_company_id    6
# minhas_notas             0
# dtype: int64

# %%
# Target e prediction
y = tmdb_rating_df.minhas_notas
X = tmdb_rating_df.drop(['minhas_notas'],axis=1)
# Dividindo em treino e validação
X_train_full,X_valid_full,y_train,y_valid = train_test_split(X,y,
                                                                       train_size=0.8,
                                                                       test_size=0.2, 
                                                                       random_state=0)

# Selecionando colunas de interesse
numerical_cols = [col_name for col_name in X_train_full.columns if X_train_full[col_name].dtype in ['int64','float64']]
my_cols = numerical_cols + ['genre_ids','original_language']
my_cols.remove('tmdb_id')
my_cols
# Out:
# ['year',
#  'popularity',
#  'vote_count',
#  'vote_average',
#  'budget',
#  'revenue',
#  'runtime',
#  'production_company_id',
#  'genre_ids',
#  'original_language']

# %%
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()

# %%
# Transformando a variável categórica 'original_language' em numérica
label_X_train = X_train.copy()
label_X_valid = X_valid.copy()

ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1)
label_X_train['original_language'] = ordinal_encoder.fit_transform(X_train[['original_language']])
label_X_valid['original_language'] = ordinal_encoder.transform(X_valid[['original_language']])

# %%
# Tirando os generos da lista criando uma linha para cada genero em cada filme
genres_X_train = label_X_train.copy()
genres_X_valid = label_X_valid.copy()

genres_X_train = genres_X_train.explode('genre_ids')
genres_X_valid = genres_X_valid.explode('genre_ids')

# %%
# Criando uma coluna para cada gênero e reagrupando os filmes
oh_encoder = OneHotEncoder(handle_unknown='ignore',sparse_output=False)
oh_genres_train = pd.DataFrame(oh_encoder.fit_transform(genres_X_train[['genre_ids']]))
oh_genres_valid = pd.DataFrame(oh_encoder.transform(genres_X_valid[['genre_ids']]))

oh_genres_train.index = genres_X_train.index
oh_genres_valid.index = genres_X_valid.index

genre_drop_train = genres_X_train.drop('genre_ids', axis=1)
genre_drop_valid = genres_X_valid.drop('genre_ids',axis=1)

oh_X_train = pd.concat([genre_drop_train,oh_genres_train], axis=1)
oh_X_valid = pd.concat([genre_drop_valid,oh_genres_valid], axis=1)

oh_X_train_final = oh_X_train.groupby(oh_X_train.index).max()
oh_X_valid_final = oh_X_valid.groupby(oh_X_valid.index).max()

oh_X_train_final.columns = oh_X_train_final.columns.astype(str)
oh_X_valid_final.columns = oh_X_valid_final.columns.astype(str)

# %%
# Criando uma função que retorna MAE e predict array
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds),preds

# %%
# Verificando o score sem as colunas genre_ids e production_company_id
score,pred = score_dataset(label_X_train.drop(columns=['genre_ids','production_company_id']),
              label_X_valid.drop(columns=['genre_ids','production_company_id']),y_train,y_valid)
score
# Out:
# 0.8767592592592595

# %%
# Verificando o score sem a coluna production_company_id
score, pred = score_dataset(oh_X_train_final.drop(columns=['production_company_id']),
              oh_X_valid_final.drop(columns=['production_company_id']),y_train,y_valid)
score
# Out:
# 1.1229629629629632

# %%
new_rating_df = X_valid_full.copy()
new_rating_df['minhas_notas'] = y_valid
new_rating_df['new_rating'] = pred
new_rating_df[['title','new_rating']].sort_values(by='new_rating')
# Out:
#                                                  title  new_rating
# 626                                Triangle of Sadness       1.895
# 101                                         Iron Man 2       1.940
# 452                                          The Whale       2.065
# 424                                            Tangled       2.150
# 489                                              Yi Yi       2.160
# ..                                                 ...         ...
# 614                                             Pixote       3.595
# 412                                    Son of the Mask       3.610
# 656                                             Primer       3.680
# 263  Jeanne Dielman, 23, quai du Commerce, 1080 Bru...       3.680
# 432                                            G-Force       3.885
#
# [162 rows x 2 columns]

# %%
# Criando uma função que devolve o MAE por modelo
def score_model(model, X_t, X_v, y_t, y_v):
    model.fit(X_t, y_t)
    preds = model.predict(X_v)
    return mean_absolute_error(y_v, preds)

# %%
# Iterando entre modelos de floresta com parâmetros diferentes
for i,model in enumerate(forest_models):
    score = score_model(model,
                oh_X_train_final.drop(columns=['production_company_id']),
                oh_X_valid_final.drop(columns=['production_company_id']),
                y_train,y_valid)
    print(f'model {i} score: {score}')
# Out:
# model 0 score: 1.1145061728395063
# model 1 score: 1.1375617283950619
# model 2 score: 1.1360802469135804
# model 3 score: 1.1129012345679012
# model 4 score: 1.1108950617283948

# %%
# Criando modelo xgboost
from xgboost import XGBRegressor

xgb_model = XGBRegressor(n_estimators=500, early_stopping_rounds=5)
xgb_model.fit(oh_X_train_final, y_train,
             eval_set=[(oh_X_valid_final,y_valid)],
             verbose=False)
xgb_predict = xgb_model.predict(oh_X_valid_final)
mean_absolute_error(xgb_predict,y_valid)
# Out:
# 1.0723800659179688

# %%
new_rating_df['xgb_rating'] = xgb_predict
new_rating_df[['title','minhas_notas','new_rating','xgb_rating']].sort_values(by='xgb_rating').head(10)
# Out:
#                    title  minhas_notas  new_rating  xgb_rating
# 247  The Virgin Suicides           3.5       2.445    2.354639
# 668              Torment           1.0       2.425    2.354639
# 251            Day Shift           3.0       2.445    2.354639
# 249                  RRR           4.5       2.490    2.354639
# 478            Lady Bird           4.0       2.395    2.402213
# 424              Tangled           2.0       2.150    2.402213
# 760       Over the Hedge           1.0       2.300    2.402213
# 626  Triangle of Sadness           1.0       1.895    2.402213
# 255       Happy Together           4.0       2.405    2.402213
# 499  Cha Cha Real Smooth           2.5       2.635    2.437286

# %%
new_rating_df[['title','minhas_notas','new_rating','xgb_rating']].sort_values(by='xgb_rating').tail(10)
# Out:
#                                  title  minhas_notas  new_rating  xgb_rating
# 122                                Saw           2.5       3.570    3.124328
# 204                              50/50           3.5       3.050    3.124328
# 416                              Click           2.0       2.935    3.124328
# 689                              Alien           3.0       3.360    3.226242
# 518                   Masculin Féminin           2.0       3.550    3.226242
# 392                            Hancock           1.0       2.820    3.226242
# 338        Back to the Future Part III           2.5       3.005    3.226242
# 729                         Spider-Man           2.0       3.090    3.226242
# 145  To All the Boys I've Loved Before           3.0       3.550    3.262286
# 576                      The 400 Blows           2.0       3.285    3.278830
